# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../db/seed_taz_c.csv', sep=';')

# %%
df
# Out:
#            date visite respo                                        broker  \
# 0    23/11/2018    non   EHB                                Jérôme Mainguy
# 1    14/11/2018    non   EHB                         Jerome Matias (bnpre)
# 2    20/06/2018    non   EHB                                Charles Albert
# 3    26/03/2018    oui    ZK                                 Pascal Voisin
# 4    21/03/2018    oui   EHB                               Frank Perochain
# 5    17/01/2018    oui   EHB                   Antoine Guicheteau (Nexity)
# 6    22/10/2018    non   EHB                 Enguerrand de Villette (CBRE)
# 7    04/10/2018    non   EHB                           Arthur HELIN (CBRE)
# 8    26/09/2018    non    ZK                                        Evolis
# 9    14/09/2018    non    ZK                                 Pascal Voisin
# 10   17/10/2018    non   EHB                            Antoine Guicheteau
# ...
